# %% [markdown]
# ## CCLE
# ### Elastic Net

# %%
# Elastic Net LOCOCV CCLE
# !python 2_lococv_elasticnet_CCLE.py data/response_CCLE.csv data/expression_CCLE.csv data/fingerprint_CCLE.csv data/cell_annotation_CCLE.txt -o output_2_lococv_elasticnet_CCLE
# Out:
# [START]
# [DATA] NUM_PAIRS: 5724
# [DATA] NUM_DRUGS: 12
# [DATA] NUM_CELLS: 491
# [DATA] NUM_GENES: 18926
# [DATA] NUM_SENSITIVITY: 2322
# [DATA] NUM_RESISTANCE: 3402
# {'THCA', 'COADREAD', 'others', 'LAML', 'PRAD', 'PAAD', 'BRCA', 'ESCA', 'BLCA', 'DLBC', 'CHOL', 'SKCM', 'HNSC', 'OV', 'LIHC', 'LUAD', 'UCEC', 'KIRC', 'LGG', 'STAD', 'GBM', 'MESO', 'LUSC'}
# [TIME] [1] 2022-4-26 19:47:16
# LeaveOneGroupOut.get_n_splits: 23
# [1/23] TEST_CANCER: BLCA
# [1/23] training in 5557 samples and testing in 167 samples
# [1/23] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/23] TEST_ACCURACY : 0.611
# [1/23] TEST_AUCROC : 0.533
# [1/23] TEST_Precision : 0.611
# [1/23] TEST_Recall : 1.000
# [1/23] TEST_F1 : 0.758
# [1/23] TEST_AUCPR : 0.620
# [TIME] [3] 2022-4-26 19:47:20
# [2/23] TEST_CANCER: BRCA
# [2/23] training in 5380 samples and testing in 344 samples
# [2/23] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [2/23] TEST_ACCURACY : 0.631
# [2/23] TEST_AUCROC : 0.488
# ...

# %% [markdown]
# ### Random Forest

# %%
# !python 2_lococv_randomforest_CCLE.py data/response_CCLE.csv data/expression_CCLE.csv data/fingerprint_CCLE.csv data/cell_annotation_CCLE.txt -o output_2_lococv_randomforest_CCLE
# Out:
# [START]
# [DATA] NUM_PAIRS: 5724
# [DATA] NUM_DRUGS: 12
# [DATA] NUM_CELLS: 491
# [DATA] NUM_GENES: 18926
# [DATA] NUM_SENSITIVITY: 2322
# [DATA] NUM_RESISTANCE: 3402
# {'UCEC', 'LAML', 'OV', 'MESO', 'BRCA', 'THCA', 'DLBC', 'KIRC', 'others', 'PAAD', 'LUAD', 'ESCA', 'LIHC', 'STAD', 'CHOL', 'GBM', 'LGG', 'HNSC', 'LUSC', 'COADREAD', 'BLCA', 'SKCM', 'PRAD'}
# [TIME] [1] 2022-4-26 19:47:12
# LeaveOneGroupOut.get_n_splits: 23
# [1/23] TEST_CANCER: BLCA
# [1/23] training in 5557 samples and testing in 167 samples
# [1/23] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/23] TEST_ACCURACY : 0.611
# [1/23] TEST_AUCROC : 0.548
# [1/23] TEST_Precision : 0.611
# [1/23] TEST_Recall : 1.000
# [1/23] TEST_F1 : 0.758
# [1/23] TEST_AUCPR : 0.643
# [TIME] [3] 2022-4-26 19:47:16
# [2/23] TEST_CANCER: BRCA
# [2/23] training in 5380 samples and testing in 344 samples
# [2/23] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [2/23] TEST_ACCURACY : 0.631
# [2/23] TEST_AUCROC : 0.516
# ...

# %% [markdown]
# ### RefDNN

# %%
# !python 2_lococv_RefDNN_CCLE.py data/response_CCLE.csv data/expression_CCLE.csv data/fingerprint_CCLE.csv data/cell_annotation_CCLE.txt -o output_2_lococv_RefDNN_CCLE
# Out:
# [START]
# [DATA] NUM_PAIRS: 5724
# [DATA] NUM_DRUGS: 12
# [DATA] NUM_CELLS: 491
# [DATA] NUM_GENES: 18926
# [DATA] NUM_SENSITIVITY: 2322
# [DATA] NUM_RESISTANCE: 3402
# {'KIRC', 'OV', 'GBM', 'DLBC', 'COADREAD', 'LUSC', 'PRAD', 'CHOL', 'BRCA', 'PAAD', 'LAML', 'BLCA', 'LUAD', 'UCEC', 'SKCM', 'HNSC', 'ESCA', 'MESO', 'others', 'THCA', 'LIHC', 'STAD', 'LGG'}
# [TIME] [1] 2022-4-27 19:56:37
# LeaveOneGroupOut.get_n_splits: 23
# [1/23] TEST_CANCER: BLCA
# [1/23] training in 5557 samples and testing in 167 samples
# [1/23] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/23] TEST_ACCURACY : 0.922
# [1/23] TEST_AUCROC : 0.950
# [1/23] TEST_Precision : 0.901
# [1/23] TEST_Recall : 0.980
# [1/23] TEST_F1 : 0.939
# [1/23] TEST_AUCPR : 0.962
# [TIME] [3] 2022-4-27 19:57:25
# [2/23] TEST_CANCER: BRCA
# [2/23] training in 5380 samples and testing in 344 samples
# [2/23] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [2/23] TEST_ACCURACY : 0.875
# [2/23] TEST_AUCROC : 0.905
# ...

# %% [markdown]
# ## GDSC
# ### Elastic Net

# %%
# !python 2_lococv_elasticnet_GDSC.py data/response_GDSC.csv data/expression_GDSC.csv data/fingerprint_GDSC.csv data/cell_annotation_GDSC.txt -o output_2_lococv_elasticnet_GDSC
# Out:
# [START]
# [DATA] NUM_PAIRS: 190036
# [DATA] NUM_DRUGS: 222
# [DATA] NUM_CELLS: 983
# [DATA] NUM_GENES: 17780
# [DATA] NUM_SENSITIVITY: 69430
# [DATA] NUM_RESISTANCE: 120606
# {'LIHC', 'MM', 'LUAD', 'LAML', 'BRCA', 'GBM', 'OV', 'LUSC', 'DLBC', 'LGG', 'PAAD', 'NB', 'SKCM', 'CESC', 'SCLC', 'ACC', 'others', 'ALL', 'ESCA', 'CLL', 'BLCA', 'MESO', 'KIRC', 'THCA', 'UCEC', 'COAD/READ', 'HNSC', 'PRAD', 'STAD', 'LCML', 'MB'}
# [TIME] [1] 2022-4-26 19:50:17
# LeaveOneGroupOut.get_n_splits: 31
# [1/31] TEST_CANCER: ACC
# [1/31] training in 189846 samples and testing in 190 samples
# [1/31] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/31] TEST_ACCURACY : 0.711
# [1/31] TEST_AUCROC : 0.500
# [1/31] TEST_AUCPR : 0.711
# [TIME] [3] 2022-4-26 19:52:8
# [2/31] TEST_CANCER: ALL
# [2/31] training in 184858 samples and testing in 5178 samples
# [2/31] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# ...

# %% [markdown]
# ### Random Forest

# %%
# GDSC
# !python 2_lococv_randomforest_GDSC.py data/response_GDSC.csv data/expression_GDSC.csv data/fingerprint_GDSC.csv data/cell_annotation_GDSC.txt -o output_2_lococv_randomforest_GDSC
# Out:
# [START]
# [DATA] NUM_PAIRS: 190036
# [DATA] NUM_DRUGS: 222
# [DATA] NUM_CELLS: 983
# [DATA] NUM_GENES: 17780
# [DATA] NUM_SENSITIVITY: 69430
# [DATA] NUM_RESISTANCE: 120606
# {'CLL', 'LIHC', 'ACC', 'CESC', 'LAML', 'MB', 'GBM', 'OV', 'others', 'NB', 'LGG', 'PRAD', 'LUSC', 'SCLC', 'ESCA', 'LCML', 'DLBC', 'UCEC', 'KIRC', 'MM', 'BRCA', 'COAD/READ', 'ALL', 'HNSC', 'STAD', 'SKCM', 'THCA', 'BLCA', 'LUAD', 'MESO', 'PAAD'}
# [TIME] [1] 2022-4-26 19:50:8
# LeaveOneGroupOut.get_n_splits: 31
# [1/31] TEST_CANCER: ACC
# [1/31] training in 189846 samples and testing in 190 samples
# [1/31] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/31] TEST_ACCURACY : 0.711
# [1/31] TEST_AUCROC : 0.500
# [1/31] TEST_Precision : 0.711
# [1/31] TEST_Recall : 1.000
# [1/31] TEST_F1 : 0.831
# [1/31] TEST_AUCPR : 0.711
# [TIME] [3] 2022-4-26 19:52:52
# [2/31] TEST_CANCER: ALL
# [2/31] training in 184858 samples and testing in 5178 samples
# [2/31] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# ...

# %% [markdown]
# ### RefDNN

# %%
# !python 2_lococv_RefDNN_GDSC.py data/response_GDSC.csv data/expression_GDSC.csv data/fingerprint_GDSC.csv data/cell_annotation_GDSC.txt -o output_2_lococv_RefDNN_GDSC
# Out:
# [START]
# [DATA] NUM_PAIRS: 190036
# [DATA] NUM_DRUGS: 222
# [DATA] NUM_CELLS: 983
# [DATA] NUM_GENES: 17780
# [DATA] NUM_SENSITIVITY: 69430
# [DATA] NUM_RESISTANCE: 120606
# {'STAD', 'BLCA', 'MM', 'GBM', 'LUAD', 'SKCM', 'ALL', 'ACC', 'PAAD', 'LAML', 'OV', 'CESC', 'MB', 'SCLC', 'PRAD', 'LIHC', 'HNSC', 'ESCA', 'CLL', 'others', 'LGG', 'COAD/READ', 'NB', 'KIRC', 'BRCA', 'DLBC', 'MESO', 'UCEC', 'LCML', 'LUSC', 'THCA'}
# [TIME] [1] 2022-4-27 19:33:34
# LeaveOneGroupOut.get_n_splits: 31
# [1/31] TEST_CANCER: ACC
# [1/31] training in 189846 samples and testing in 190 samples
# [1/31] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/31] TEST_ACCURACY : 0.805
# [1/31] TEST_AUCROC : 0.874
# [1/31] TEST_Precision : 0.889
# [1/31] TEST_Recall : 0.830
# [1/31] TEST_F1 : 0.858
# [1/31] TEST_AUCPR : 0.929
# [TIME] [3] 2022-4-27 19:37:7
# [2/31] TEST_CANCER: ALL
# [2/31] training in 184858 samples and testing in 5178 samples
# [2/31] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# ...
