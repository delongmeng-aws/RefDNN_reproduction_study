# %% [markdown]
# ## CCLE
# ### Elastic Net

# %%
# Elastic Net LODOCV CCLE
# !python 3_lodocv_elasticnet_CCLE.py data/response_CCLE.csv data/expression_CCLE.csv data/fingerprint_CCLE.csv -o output_3_lodocv_elasticnet_CCLE
# Out:
# [START]
# [DATA] NUM_PAIRS: 5724
# [DATA] NUM_DRUGS: 12
# [DATA] NUM_CELLS: 491
# [DATA] NUM_GENES: 18926
# [DATA] NUM_SENSITIVITY: 2322
# [DATA] NUM_RESISTANCE: 3402
# [TIME] [1] 2022-4-26 19:47:8
# LeaveOneGroupOut.get_n_splits: 12
# [1/12] TEST_DRUG: Erlotinib
# [1/12] training in 5234 samples and testing in 490 samples
# [1/12] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/12] TEST_ACCURACY : 0.539
# [1/12] TEST_AUCROC : 0.559
# [1/12] TEST_Precision : 0.929
# [1/12] TEST_Recall : 0.547
# [1/12] TEST_F1 : 0.689
# [1/12] TEST_AUCPR : 0.956
# [TIME] [3] 2022-4-26 19:47:12
# [2/12] TEST_DRUG: Lapatinib
# [2/12] training in 5233 samples and testing in 491 samples
# [2/12] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [2/12] TEST_ACCURACY : 0.908
# [2/12] TEST_AUCROC : 0.539
# [2/12] TEST_Precision : 0.908
# [2/12] TEST_Recall : 1.000
# [2/12] TEST_F1 : 0.952
# [2/12] TEST_AUCPR : 0.924
# [TIME] [3] 2022-4-26 19:47:15
# [3/12] TEST_DRUG: Nilotinib
# ...

# %% [markdown]
# ### Random Forest

# %%
# Random Forest LODOCV CCLE
# !python 3_lodocv_randomforest_CCLE.py data/response_CCLE.csv data/expression_CCLE.csv data/fingerprint_CCLE.csv -o output_3_lodocv_randomforest_CCLE
# Out:
# [START]
# [DATA] NUM_PAIRS: 5724
# [DATA] NUM_DRUGS: 12
# [DATA] NUM_CELLS: 491
# [DATA] NUM_GENES: 18926
# [DATA] NUM_SENSITIVITY: 2322
# [DATA] NUM_RESISTANCE: 3402
# [TIME] [1] 2022-4-26 19:47:5
# LeaveOneGroupOut.get_n_splits: 12
# [1/12] TEST_DRUG: Erlotinib
# [1/12] training in 5234 samples and testing in 490 samples
# [1/12] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/12] TEST_ACCURACY : 0.867
# [1/12] TEST_AUCROC : 0.662
# [1/12] TEST_Precision : 0.930
# [1/12] TEST_Recall : 0.928
# [1/12] TEST_F1 : 0.929
# [1/12] TEST_AUCPR : 0.966
# [TIME] [3] 2022-4-26 19:47:8
# [2/12] TEST_DRUG: Lapatinib
# [2/12] training in 5233 samples and testing in 491 samples
# [2/12] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [2/12] TEST_ACCURACY : 0.872
# [2/12] TEST_AUCROC : 0.615
# [2/12] TEST_Precision : 0.908
# [2/12] TEST_Recall : 0.955
# [2/12] TEST_F1 : 0.931
# [2/12] TEST_AUCPR : 0.938
# [TIME] [3] 2022-4-26 19:47:11
# [3/12] TEST_DRUG: Nilotinib
# ...

# %% [markdown]
# ### RefDNN

# %%
# !python 3_lodocv_RefDNN_CCLE.py data/response_CCLE.csv data/expression_CCLE.csv data/fingerprint_CCLE.csv -o output_3_lodocv_RefDNN_CCLE
# Out:
# [START]
# [DATA] NUM_PAIRS: 5724
# [DATA] NUM_DRUGS: 12
# [DATA] NUM_CELLS: 491
# [DATA] NUM_GENES: 18926
# [DATA] NUM_SENSITIVITY: 2322
# [DATA] NUM_RESISTANCE: 3402
# [TIME] [1] 2022-4-27 19:42:18
# LeaveOneGroupOut.get_n_splits: 12
# [1/12] TEST_DRUG: Erlotinib
# [1/12] training in 5234 samples and testing in 490 samples
# [1/12] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# /opt/miniconda3/envs/RefDNN/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [1/12] TEST_ACCURACY : 0.067
# [1/12] TEST_AUCROC : 0.579
# [1/12] TEST_Precision : 0.000
# [1/12] TEST_Recall : 0.000
# [1/12] TEST_F1 : 0.000
# [1/12] TEST_AUCPR : 0.953
# [TIME] [3] 2022-4-27 19:43:4
# [2/12] TEST_DRUG: Lapatinib
# [2/12] training in 5233 samples and testing in 491 samples
# ...

# %% [markdown]
# ## GDSC
# ### Elastic Net

# %%
# Elastic Net LODOCV GDSC
# !python 3_lodocv_elasticnet_GDSC.py data/response_GDSC.csv data/expression_GDSC.csv data/fingerprint_GDSC.csv -o output_3_lodocv_elasticnet_GDSC
# Out:
# [START]
# [DATA] NUM_PAIRS: 190036
# [DATA] NUM_DRUGS: 222
# [DATA] NUM_CELLS: 983
# [DATA] NUM_GENES: 17780
# [DATA] NUM_SENSITIVITY: 69430
# [DATA] NUM_RESISTANCE: 120606
# [TIME] [1] 2022-4-26 19:49:57
# LeaveOneGroupOut.get_n_splits: 222
# [1/222] TEST_DRUG: (5Z)-7-Oxozeaenol
# [1/222] training in 189118 samples and testing in 918 samples
# [1/222] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/222] TEST_ACCURACY : 0.101
# [1/222] TEST_AUCROC : 0.681
# [1/222] TEST_Precision : 0.100
# [1/222] TEST_Recall : 1.000
# [1/222] TEST_F1 : 0.182
# [1/222] TEST_AUCPR : 0.234
# [TIME] [3] 2022-4-26 19:52:3
# [2/222] TEST_DRUG: 5-Fluorouracil
# [2/222] training in 189122 samples and testing in 914 samples
# [2/222] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [2/222] TEST_ACCURACY : 0.672
# [2/222] TEST_AUCROC : 0.722
# [2/222] TEST_Precision : 0.639
# [2/222] TEST_Recall : 0.905
# [2/222] TEST_F1 : 0.749
# [2/222] TEST_AUCPR : 0.735
# [TIME] [3] 2022-4-26 19:54:38
# ...

# %% [markdown]
# ### Random Forest

# %%
# !python 3_lodocv_randomforest_GDSC.py data/response_GDSC.csv data/expression_GDSC.csv data/fingerprint_GDSC.csv -o output_3_lodocv_randomforest_GDSC
# Out:
# [START]
# [DATA] NUM_PAIRS: 190036
# [DATA] NUM_DRUGS: 222
# [DATA] NUM_CELLS: 983
# [DATA] NUM_GENES: 17780
# [DATA] NUM_SENSITIVITY: 69430
# [DATA] NUM_RESISTANCE: 120606
# [TIME] [1] 2022-4-26 19:49:46
# LeaveOneGroupOut.get_n_splits: 222
# [1/222] TEST_DRUG: (5Z)-7-Oxozeaenol
# [1/222] training in 189118 samples and testing in 918 samples
# [1/222] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [1/222] TEST_ACCURACY : 0.160
# [1/222] TEST_AUCROC : 0.791
# [1/222] TEST_Precision : 0.106
# [1/222] TEST_Recall : 0.989
# [1/222] TEST_F1 : 0.191
# [1/222] TEST_AUCPR : 0.366
# [TIME] [3] 2022-4-26 19:52:32
# [2/222] TEST_DRUG: 5-Fluorouracil
# [2/222] training in 189122 samples and testing in 914 samples
# [2/222] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# [2/222] TEST_ACCURACY : 0.600
# [2/222] TEST_AUCROC : 0.802
# [2/222] TEST_Precision : 0.575
# [2/222] TEST_Recall : 0.988
# [2/222] TEST_F1 : 0.727
# [2/222] TEST_AUCPR : 0.785
# [TIME] [3] 2022-4-26 19:55:16
# ...

# %% [markdown]
# ### RefDNN

# %%
# GDSC lodocv_RefDNN
# !python 3_lodocv_RefDNN_GDSC.py data/response_GDSC.csv data/expression_GDSC.csv data/fingerprint_GDSC.csv -o output_3_lodocv_RefDNN_GDSC
# Out:
# [START]
# [DATA] NUM_PAIRS: 190036
# [DATA] NUM_DRUGS: 222
# [DATA] NUM_CELLS: 983
# [DATA] NUM_GENES: 17780
# [DATA] NUM_SENSITIVITY: 69430
# [DATA] NUM_RESISTANCE: 120606
# [TIME] [1] 2022-4-27 6:7:58
# LeaveOneGroupOut.get_n_splits: 222
# [1/222] TEST_DRUG: (5Z)-7-Oxozeaenol
# [1/222] training in 189118 samples and testing in 918 samples
# [1/222] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# 2022-04-27 06:08:08.783595: W tensorflow/core/framework/allocator.cc:122] Allocation of 10760029280 exceeds 10% of system memory.
# [1/222] TEST_ACCURACY : 0.187
# [1/222] TEST_AUCROC : 0.797
# [1/222] TEST_Precision : 0.109
# [1/222] TEST_Recall : 0.989
# [1/222] TEST_F1 : 0.196
# [1/222] TEST_AUCPR : 0.365
# [TIME] [3] 2022-4-27 6:11:42
# [2/222] TEST_DRUG: 5-Fluorouracil
# [2/222] training in 189122 samples and testing in 914 samples
# [2/222] NOW TRAINING THE MODEL WITH BEST PARAMETERS...
# ...
